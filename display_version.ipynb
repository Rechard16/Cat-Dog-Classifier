# %% [markdown]
# # Dispaly
# You can add your own photo to test our best model.
# Just put your photo in our folder.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras import regularizers
from tensorflow.keras.utils import plot_model
import pickle
import numpy as np
import PIL.Image as Image
import os
import matplotlib.pyplot as plt
import cv2 as cv
import seaborn as sns
import pandas as pd
import sklearn.linear_model as lm

# %%
#load model
model = tf.keras.models.load_model('difker_best.h5')

# %%
# Load data

# %%
img=cv.imread('photo3.jpg',0)#change it to your photo name
#resize image
X=cv.resize(img,(128,128))
X= np.array(X).reshape(-1, 128,128, 1)

# %%
#predict
prediction=model.predict(X)

# %%
#show result，dog is 0 and cat is 1
print(prediction)
# Out:
# [[1.]]

# %%
#show image
plt.imshow(img)
